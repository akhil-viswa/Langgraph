# %%
from  langchain_ollama import ChatOllama

# %%
model = ChatOllama(
    model="llama3.2:3b",
    temperature=0
)

# %%
response = model.invoke("What is RAG?")
print(response.content)
# Out:
# RAG can refer to different things, but here are a few possible meanings:
#
# 1. RAG (Radio Active Gas): In nuclear physics, RAG refers to radioactive gases, such as radon, which are emitted from certain radioactive materials.
# 2. RAG (Resin Acid Gas): In the paper industry, RAG refers to resin acid gas, a byproduct of the pulping process that can be used as a raw material for the production of paper chemicals.
# 3. RAG (Resin Acid Gas) Treatment: This is a process used to treat RAG emissions from paper mills, which involves the use of a catalyst to convert the RAG into a more useful chemical.
# 4. RAG (Resin Acid Gas) Recovery: This is a process used to recover RAG from paper mill effluent, which involves the use of a solvent to extract the RAG from the wastewater.
# 5. RAG (Resin Acid Gas) Recycling: This is a process used to recycle RAG from paper mill waste, which involves the use of a catalyst to convert the RAG into a more useful chemical.
#
# ...
